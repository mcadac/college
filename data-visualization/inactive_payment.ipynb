# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('data/inactive_payment_error_tx_total.csv')
df
# Out:
#         to_char red_financiera_pagos  count
# 0    2021-02-01             BANCOMER     96
# 1    2021-02-01              BANORTE     63
# 2    2021-02-01                CIELO      2
# 3    2021-02-01           CREDIBANCO    137
# 4    2021-02-01               EFECTY      3
# ..          ...                  ...    ...
# 107  2021-02-08             REDECARD      2
# 108  2021-02-08     TRANSBANK_DIRECT      1
# 109  2021-02-08         TRANSBANK_V2     10
# 110  2021-02-08              VISA_AR      5
# 111  2021-02-08        VISANET_PE_V3     13
#
# [112 rows x 3 columns]

# %%
figure(num=None, figsize=(22, 20), dpi=80, facecolor='w', edgecolor='k')

for network in df['red_financiera_pagos'].drop_duplicates():
    print(network)
    networks = df[df['red_financiera_pagos'] == network]
    date = networks['to_char']
    count = networks['count']
    plt.plot(date,count,label=network)
    plt.legend(loc='upper left')
# Out:
# BANCOMER
# BANORTE
# CIELO
# CREDIBANCO
# EFECTY
# FIRSTDATA
# GTECH
# OXXO
# PAGOEFECTIVO
# PAYU_TEST
# PRISMA_AR
# PROCESOS_MC_PE_ENC
# PSE
# REDEBAN
# REDECARD
# TRANSBANK_DIRECT
# TRANSBANK_V2
# VISA_AR
# VISANET_PE_V3
# AMEX_AR
# AMEX_MX
# BANCOLOMBIA
# DAVIVIENDA
# DIESTEL
# NPS_AR
# STP
# TRANSBANK_DEBIT

# %%
df.groupby(['red_financiera_pagos'], as_index=False)['count'].max()
# Out:
#    red_financiera_pagos  count
# 0               AMEX_AR      8
# 1               AMEX_MX      3
# 2           BANCOLOMBIA    115
# 3              BANCOMER    217
# 4               BANORTE     76
# 5                 CIELO    504
# 6            CREDIBANCO    137
# 7            DAVIVIENDA      1
# 8               DIESTEL      2
# 9                EFECTY    164
# 10            FIRSTDATA     12
# 11                GTECH     85
# 12               NPS_AR     16
# 13                 OXXO     18
# 14         PAGOEFECTIVO     11
# 15            PAYU_TEST      7
# 16            PRISMA_AR      4
# 17   PROCESOS_MC_PE_ENC    202
# 18                  PSE    580
# 19              REDEBAN    117
# 20             REDECARD    265
# 21                  STP     14
# 22      TRANSBANK_DEBIT     56
# 23     TRANSBANK_DIRECT     91
# 24         TRANSBANK_V2     77
# 25        VISANET_PE_V3    240
# 26              VISA_AR    133

# %% [markdown]
# *Remove missing values*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   to_char               112 non-null    object
#  1   red_financiera_pagos  112 non-null    object
#  2   count                 112 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ KB
